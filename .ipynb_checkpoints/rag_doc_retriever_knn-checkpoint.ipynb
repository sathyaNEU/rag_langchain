# %% [markdown]
# `(2) LangSmith`
#
# https://docs.smith.langchain.com/

# %%
import os
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = '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'

# %% [markdown]
# `(3) API Keys`

# %%
os.environ['OPENAI_API_KEY'] = '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'

# %% [markdown]
# ## Part 1: Overview
#
# [RAG quickstart](https://python.langchain.com/docs/use_cases/question_answering/quickstart)

# %%
import bs4
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # Indexing

# %% [markdown]
# ### Load Documents

# %%
loader = WebBaseLoader(
    web_paths=("https://medium.com/@sathya8571/unveiling-the-odds-a-deep-dive-into-blackjack-analysis-with-power-bi-and-python-a464610d6c0f",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            # class_=("post-content", "post-title", "post-header")
            id=("b55f", "ebf9", "7fe3", "fed7", "9a5a", "0e43", "e4ba", "40c2", "209b", "ad95", "c5a9", "c0ca", "cfe8")
        )
    ),
)
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'https://medium.com/@sathya8571/unveiling-the-odds-a-deep-dive-into-blackjack-analysis-with-power-bi-and-python-a464610d6c0f'}, page_content='The Odds of WinningIn my study, I calculated the average probability of winning when hitting on a 12 against a dealer showing a 10 to be 42.39%. This figure may seem low, but it is crucial to consider the broader context of the game:Players face odds that are nearly 20% lower than average, making it imperative to strategize effectively.The analysis further explores different dealer upcards and their impact on player odds. The results show the following probabilities for winning when hitting:51.67%: If hitting against a dealer showing 12 (with a push rate of 0*%)51.50%: If hitting against a dealer showing 13 (with a push rate of 0*%)51.77%: If hitting against a dealer showing 14 (with a push rate of 0*%)51.74%: If hitting against a dealer showing 15 (with a push rate of 0*%)51.98%: If hitting against a dealer showin
# ...

# %% [markdown]
# ### Split Documents

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
splits = text_splitter.split_documents(docs)

# %%
splits
# Out:
# [Document(metadata={'source': 'https://medium.com/@sathya8571/unveiling-the-odds-a-deep-dive-into-blackjack-analysis-with-power-bi-and-python-a464610d6c0f'}, page_content='The Odds of WinningIn my study, I calculated the average probability of winning when hitting on a 12 against a dealer showing a 10 to be 42.39%. This figure may seem low, but it is crucial to consider the broader context of the game:Players face odds that are nearly 20% lower than average, making it imperative to strategize effectively.The analysis further explores different dealer upcards and their impact on player odds. The results show the following probabilities for winning when'),
# ...

# %% [markdown]
# ### Embed

# %%
vectorstore = Chroma.from_documents(documents=splits, 
                                    embedding=OpenAIEmbeddings())

# %% [markdown]
# # Retrieval

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 1})

# %%
relevant_docs = retriever.get_relevant_documents("If a dealer shows 14, what are the odds for the player to win if he hits?")

# %%
relevant_docs
# Out:
# [Document(metadata={'source': 'https://medium.com/@sathya8571/unveiling-the-odds-a-deep-dive-into-blackjack-analysis-with-power-bi-and-python-a464610d6c0f'}, page_content='and their impact on player odds. The results show the following probabilities for winning when hitting:51.67%: If hitting against a dealer showing 12 (with a push rate of 0*%)51.50%: If hitting against a dealer showing 13 (with a push rate of 0*%)51.77%: If hitting against a dealer showing 14 (with a push rate of 0*%)51.74%: If hitting against a dealer showing 15 (with a push rate of 0*%)51.98%: If hitting against a dealer showing 16 (with a push rate of 0*%)51.83%: If hitting against a dealer')]

# %% [markdown]
# # Generation

# %% [markdown]
# ## Part 4: Generation
#
# ![Screenshot 2024-02-12 at 1.37.38 PM.png](attachment:f9b0e284-58e4-4d33-9594-2dad351c569a.png)

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# Prompt
template = """Answer the question based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Answer the question based only on the following context:\n{context}\n\nQuestion: {question}\n'), additional_kwargs={})])

# %%
#LLM
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
# Chain
chain = prompt | llm

# %%
chain.invoke({"context":relevant_docs,"question":"What are the odds of hitting if a dealer shows 14 ?"})

# %% [markdown]
# ### How to validate whether the document fitlered by the retriever was good enough to feed the LLM

# %%
# Documents
question = "What are the odds of hitting if a dealer shows 14 ?"
document = relevant_docs[0].page_content

# %% [markdown]
# [Count tokens](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb) considering [~4 char / token](https://help.openai.com/en/articles/4936856-what-are-tokens-and-how-to-count-them)

# %%
import tiktoken

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

num_tokens_from_string(question, "cl100k_base")
# Out:
# 13

# %% [markdown]
# [Text embedding models](https://python.langchain.com/docs/integrations/text_embedding/openai)

# %%
from langchain_openai import OpenAIEmbeddings
embd = OpenAIEmbeddings()
query_result = embd.embed_query(question)
document_result = embd.embed_query(document)

# %%
print(query_result)
print(document_result)
# Out:
# [-0.0013222225243225694, -0.01756208762526512, -0.004576274659484625, -0.011786862276494503, -0.03747479245066643, 0.0008958352846093476, -0.026586297899484634, 0.003029460087418556, -0.03447572886943817, 0.004697858355939388, -0.016575908288359642, 0.015089885331690311, -0.03701547533273697, 0.00646419869735837, 0.022222794592380524, 0.0128743601962924, 0.021898571401834488, -0.013462015427649021, 0.0019943099468946457, -0.03690740093588829, -0.025897324085235596, -0.0005078651593066752, -0.0066634612157940865, -0.011611240915954113, -0.000587654416449368, 0.014076688326895237, 0.026072943583130836, 0.0036069825291633606, 0.005923827178776264, -0.01680556684732437, 0.025721702724695206, 0.027585985139012337, -0.035070136189460754, -0.009746958501636982, -0.0236007422208786, -0.00560973584651947, 0.012408290058374405, 0.01456302311271429, -0.008740515448153019, -0.004907252267003059, 0.02173645980656147, -0.0040561663918197155, -0.006487840320914984, -0.007869165390729904, 0.00048928
# ...

# %% [markdown]
# [Cosine similarity](https://platform.openai.com/docs/guides/embeddings/frequently-asked-questions) is reccomended (1 indicates identical) for OpenAI embeddings.

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

similarity = cosine_similarity(query_result, document_result)
print("Cosine Similarity:", similarity)
# Out:
# Cosine Similarity: 0.8632140979982025

# %% [markdown]
# [Document Loaders](https://python.langchain.com/docs/integrations/document_loaders/)

# %% [markdown]
# [Vectorstores](https://python.langchain.com/docs/integrations/vectorstores/)

# %% [markdown]
# ## Generation Flow Diagram
#
# ![Screenshot 2024-02-12 at 1.37.38 PM.png](attachment:f9b0e284-58e4-4d33-9594-2dad351c569a.png)
